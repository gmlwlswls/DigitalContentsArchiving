# %%
# !pip install openpyxl

# %%
from DigitalContentsArchiving import DigitalContentsArchiving

# %%
digit_contents_archiving_test = DigitalContentsArchiving('D:/00. Test/Belif')

# %%
# 1. DocNum CSV 파일 생성 시 주의 사항

# zip파일 다 풀 것 - *.zip
# csv파일 형식으로 저장

# generate_DocNum_df = digit_contents_archiving.generate_DocNum_dataframe('D:/00. Test/누끼컷 모음', start_doc_num= 1)
# generate_DocNum_df.tail()
# generate_DocNum_df.info()

# > 파이선으로는 중복 파일 필터가 안됨(1030 > 994)
# > 엑셀 파일로 생성하면 중복 파일 자동으로 제거

# %%
# # 2. 네이버 드라이브 폴더 내 파일명 변환
# # 문서 번호_파일명

# # 1) 누끼컷 모음
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_csv/naver_drive_누끼컷모음.csv',
#                                                        'D:/00. Test/누끼컷 모음')

# # 2) 연출컷 모음
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_csv/naver_drive_연출컷모음.csv',
#                                                        'D:/00. Test/연출컷 모음')

# # 3) 영상(유니버스 제외)
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_csv/naver_drive_영상(유니버스 제외).csv',
#                                                        'D:/00. Test/영상(유니버스 제외)')

# # 4) 인스타그램
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/naver_drive_인스타그램_Instagram.xlsx',
#                                                        'E:/01. 빌리프_컨텐츠아카이빙/01. 빌리프 드라이브/06. 인스타그램_Instagram/인스타그램_Instagram')

# 5) Overseas
digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/naver_drive_Overseas.xlsx',
                                                       'F:/12. Overseas/Belif overseas')
# Out:
# ✅ Renamed: F:/12. Overseas/Belif overseas\belif Brand story_NOV.28.pptx -> F:/12. Overseas/Belif overseas\DOC11127_belif Brand story_NOV.28.pptx
# ✅ Renamed: F:/12. Overseas/Belif overseas\빌리프 한국매장 사진_211216.zip -> F:/12. Overseas/Belif overseas\DOC11128_빌리프 한국매장 사진_211216.zip
# ✅ Renamed: F:/12. Overseas/Belif overseas\빌리프_브랜드 소개장표F_2211.pptx -> F:/12. Overseas/Belif overseas\DOC11129_빌리프_브랜드 소개장표F_2211.pptx
# ✅ Renamed: F:/12. Overseas/Belif overseas\1. ADPR\(Glowpick) 2020_WINNER.rgb_수분크림.ai -> F:/12. Overseas/Belif overseas\1. ADPR\DOC11130_(Glowpick) 2020_WINNER.rgb_수분크림.ai
# ✅ Renamed: F:/12. Overseas/Belif overseas\1. ADPR\1109_[해외용] 미국_아쿠아밤브라이트닝 비타민 C 크림_연출컷_라벨수정_Q.jpg -> F:/12. Overseas/Belif overseas\1. ADPR\DOC11131_1109_[해외용] 미국_아쿠아밤브라이트닝 비타민 C 크림_연출컷_라벨수정_Q.jpg
# ✅ Renamed: F:/12. Overseas/Belif overseas\1. ADPR\AD\super drops\SUPER_cha.ai -> F:/12. Overseas/Belif overseas\1. ADPR\AD\super drops\DOC11132_SUPER_cha.ai
# ...

# %%
# 2-2. 끼 드라이브 폴더 내 파일명 변환
# 문서 번호_파일명

# 1) 연출컷 모음
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/끼드라이브_연출컷모음.xlsx',
#                                                        'D:/00. Test/끼 스튜디오 드라이브/연출컷 모음')

# # 2) 제품 및 세트 누끼 모음
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/끼드라이브_제품및세트누끼모음.xlsx',
#                                                        'D:/00. Test/끼 스튜디오 드라이브/제품 및 세트 누끼 모음')

# 3) 제형 이미지 모음
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/끼드라이브_제형이미지모음.xlsx',
#                                                        'D:/02. 끼 스튜디오 드라이브/빌리프 끼 아카이빙 컨텐츠_250324/03. 제형 이미지 모음')

# 4) 판촉 이미지 모음
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/끼드라이브_판촉이미지모음.xlsx',
#                                                        'D:/02. 끼 스튜디오 드라이브/빌리프 끼 아카이빙 컨텐츠_250324/04. 판촉 이미지 모음')

# 5) 월간 DM 데이터 모음
# digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/끼드라이브_월간DM데이터모음.xlsx',
#                                                        'D:/02. 끼 스튜디오 드라이브/빌리프 끼 아카이빙 컨텐츠_250324/05. 월간 DM 데이터 모음')

# 6) DM 연출컷
digit_contents_archiving_test.rename_naver_with_DocNum('D:/00. Test/00. naver_drive_xlsx/끼드라이브_DM연출컷모음.xlsx',
                                                       'D:/02. 끼 스튜디오 드라이브/빌리프 끼 아카이빙 컨텐츠_250324/06. DM 연출컷')

# %%
# 3. 로컬 이사 완료 후 폴더트리 내 변수명 변경
# 문서 번호_제품명_용량_상위 폴더명_최종 수정일
# 오류) 제품명 대소문자만 다르면 rename에 실패해서

digit_contents_archiving_test.rename()
# Out:
# Renaming: 2D
# Renaming: 3D
# Renaming: Cutout
# Renaming: DM
# Renaming: Leaflet
# Renaming: Logo
# Renaming: Promotion
# Renaming: Video
# Renaming: OliveYoung
# Renaming: Overseas
# Renaming: TaxFree
# Renaming: AquaBombJumbo
# Renaming: Gratitude
# Renaming: Holiday
# Renaming: MoisturizingBombJumbo
# Renaming: NewYear
# Renaming: Summer
# Renaming: ThanksGiving
# Renaming: Kakaotalk
# Renaming: OliveYoung
# Renaming: Overseas
# Renaming: TaxFree
# Renaming: AquaBombJumbo
# Renaming: Gratitude
# Renaming: Holiday
# Renaming: MoisturizingBombJumbo
# Renaming: NewYear
# Renaming: Summer
# Renaming: ThanksGiving
# Renaming: Kakaotalk
# Renaming: OliveYoung
# Renaming: Overseas
# Renaming: TaxFree
# Renaming: AquaBombJumbo
# Renaming: Gratitude
# Renaming: Holiday
# Renaming: MoisturizingBombJumbo
# Renaming: NewYear
# Renaming: Summer
# Renaming: ThanksGiving
# Renaming: Kakaotalk
# Renaming: OliveYoung
# Renaming: Overseas
# Renaming: TaxFree
# Renaming: AquaBombJumbo
# ...

# %%
# digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/naver_drive_누끼컷모음.xlsx',
#                                                              'D:/00. Test/01. naver_google_merged_xlsx/merged_누끼컷모음.xlsx')

# digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/naver_drive_연출컷모음.xlsx',
#                                                              'D:/00. Test/01. naver_google_merged_xlsx/merged_연출컷모음.xlsx')

# digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/naver_drive_영상(유니버스 제외).xlsx',
#                                                              'D:/00. Test/01. naver_google_merged_xlsx/merged_영상(유니버스 제외).xlsx')

digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/naver_drive_인스타그램_Instagram.xlsx',
                                                             'D:/00. Test/01. naver_google_merged_xlsx/merged_인스타그램_Instagram.xlsx')

digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/naver_drive_Overseas.xlsx',
                                                             'D:/00. Test/01. naver_google_merged_xlsx/merged_Overseas.xlsx')
# Out:
# ✅ 병합된 xlsx 파일 생성 완료: D:/00. Test/01. naver_google_merged_xlsx/merged_인스타그램_Instagram.xlsx
# ✅ 병합된 xlsx 파일 생성 완료: D:/00. Test/01. naver_google_merged_xlsx/merged_Overseas.xlsx

# %%
# digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/끼드라이브_연출컷모음.xlsx',
#                                                              'D:/00. Test/01. naver_google_merged_xlsx/merged_끼드라이브_연출컷모음.xlsx')

# digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/끼드라이브_제품및세트누끼모음.xlsx',
#                                                              'D:/00. Test/01. naver_google_merged_xlsx/merged_끼드라이브_제품및세트누끼모음.xlsx')

# digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/끼드라이브_제형이미지모음.xlsx',
#                                                              'D:/00. Test/01. naver_google_merged_xlsx/merged_끼드라이브_제형이미지모음.xlsx')

# digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/끼드라이브_판촉이미지모음.xlsx',
#                                                              'D:/00. Test/01. naver_google_merged_xlsx/merged_끼드라이브_판촉이미지모음.xlsx')

digit_contents_archiving_test.foldertree_to_xlsx_merge_by_doc('D:/00. Test/00. naver_drive_xlsx/끼드라이브_월간DM데이터모음.xlsx',
                                                             'D:/00. Test/01. naver_google_merged_xlsx/merged_끼드라이브_월간DM데이터모음.xlsx')
# Out:
# ✅ 병합된 xlsx 파일 생성 완료: D:/00. Test/01. naver_google_merged_xlsx/merged_끼드라이브_월간DM데이터모음.xlsx

# %%
# 4. BnA 엑셀 파일 생성 후 원래 파일명으로 복원
# 문서 번호_(구)파일명

# 함수명 : renameOriginalName() > 작성해야 함
# * 원래 파일명으로 구글 드라이브 업로드해서 메타 데이터 작성
# * 파일명 변경을 일일이 해야 함

# 변경된 파일명으로 업로드하고 메타 데이터는 문서 번호로 비교해가면서 작성해야 할 듯한데
# 근데 또 문서 번호로 업로드하면 문서 번호 삭제는 또 언제해..

# %%
# 이사 끝나면 실행
# digit_contents_archiving_test.removeDocNum()
# Out:
# Skipping brand asset folder: 0_BrandAsset
# Removing_DocNum: 0_Logo
# ✅ 문서번호 제거 완료: 총 0개 파일 이름 변경됨
# Removing_DocNum: BarrierEmulsion
# 🔁 Renamed: DOC01363_BarrierEmulsion_100ml_Product_19800101.jpg → BarrierEmulsion_100ml_Product_19800101.jpg
# 🔁 Renamed: DOC01369_BarrierEmulsion_100ml_Product_19800101.jpg → BarrierEmulsion_100ml_Product_19800101_(1).jpg
# ✅ 문서번호 제거 완료: 총 2개 파일 이름 변경됨
# Removing_DocNum: BarrierToner
# 🔁 Renamed: DOC01362_BarrierToner_120ml_Product_19800101.jpg → BarrierToner_120ml_Product_19800101.jpg
# 🔁 Renamed: DOC01368_BarrierToner_120ml_Product_19800101.jpg → BarrierToner_120ml_Product_19800101_(1).jpg
# ✅ 문서번호 제거 완료: 총 2개 파일 이름 변경됨
# Removing_DocNum: Bomb
# 🔁 Renamed: DOC00395_Bomb_50ml_Cutout_20190827.jpg → Bomb_50ml_Cutout_20190827.jpg
# 🔁 Renamed: DOC00631_Bomb_50ml_Cutout_20210223.png → Bomb_50ml_Cutout_20210223.png
# 🔁 Renamed: DOC00836_Bomb_50ml_Cutout_20210609.jpg → Bomb_50ml_Cutout_20210609.jpg
# ...
